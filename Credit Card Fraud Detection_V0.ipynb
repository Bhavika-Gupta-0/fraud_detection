# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
# loading the data and reading it through pandas
df= pd.read_csv("creditcard.csv")
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
# This will help us see all colmns at once
pd.options.display.max_columns = None

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %%
df.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9       V10       V11       V12  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  4.356170 -1.593105  2.711941
# 284803  1.058415  0.024330  0.294869  0.584800 -0.975926 -0.150189  0.915802
# 284804  3.031260 -0.296827  0.708417  0.432454 -0.484782  0.411614  0.063119
# 284805  0.623708 -0.686180  0.679145  0.392087 -0.399126 -1.933849 -0.962886
# 284806 -0.649617  1.577006 -0.414650  0.486180 -0.915427 -1.040458 -0.031513
#
#              V13       V14       V15       V16       V17       V18       V19  \
# ...

# %%
# checking size of data
df.shape
# Out:
# (284807, 31)

# %%
# check few info about our dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
# checking null values
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
# distribution of legit transactions & fraudulent transactions
df['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %% [markdown]
# #### This is highly unbalanced data set
# 0 - represents normal transaction
# 1 - represents fraudulent transaction

# %%
# seperating the data for analysis

legit = df[df.Class == 0]
fraud = df[df.Class == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (284315, 31)
# (492, 31)

# %%
# statistical measures of the data
legit.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
# compare the values for both transactions
df.groupby('Class')['Amount'].mean()
# Out:
# Class
# 0     88.291022
# 1    122.211321
# Name: Amount, dtype: float64

# %%
# Under-Sampling

# %%
# Built a sample dataset containing similar distribution of normal transactions and fraudulent tranactions

# Number of fraudulent transaction --> 492

# %%
legit_sample = legit.sample(n=492)
legit_sample
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 28898    35223.0 -0.790015  0.874647  1.711628 -1.352299  0.432771 -0.771443
# 41156    40560.0 -0.708047  1.373264  0.598922  0.782221  0.010059 -0.401528
# 111159   72120.0 -2.062005  1.005983 -0.100631  1.240645  0.585214 -0.258625
# 131697   79703.0  1.235649  0.246700  0.175407  0.506931 -0.212665 -0.576058
# 259878  159314.0 -0.352799  0.922197  0.936538 -0.067338 -0.738263  0.282153
# ...          ...       ...       ...       ...       ...       ...       ...
# 114309   73428.0 -0.803257 -0.047886  1.554706 -1.538927  0.080989 -1.583633
# 121433   76190.0  1.099168 -1.652857  0.730081 -1.307040 -1.842713 -0.075141
# 198675  132602.0 -0.329746  1.054387 -0.310578 -0.157425  0.675248  0.078379
# 149331   91034.0 -0.251163  1.223851 -0.006040 -0.651568  1.486648 -0.721204
# 280784  169749.0 -1.281419  0.458443 -0.925240  0.272459  0.862928 -1.200325
#
# ...

# %%
# concatenating two datasets

new_df = pd.concat([legit_sample, fraud], axis=0)

# %%
new_df.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 28898    35223.0 -0.790015  0.874647  1.711628 -1.352299  0.432771 -0.771443
# 41156    40560.0 -0.708047  1.373264  0.598922  0.782221  0.010059 -0.401528
# 111159   72120.0 -2.062005  1.005983 -0.100631  1.240645  0.585214 -0.258625
# 131697   79703.0  1.235649  0.246700  0.175407  0.506931 -0.212665 -0.576058
# 259878  159314.0 -0.352799  0.922197  0.936538 -0.067338 -0.738263  0.282153
#
#               V7        V8        V9       V10       V11       V12       V13  \
# 28898   1.043877 -0.084335 -0.709816 -1.101380  0.004284  0.413590  0.536061
# 41156   0.754722  0.232850 -0.924845 -0.342857 -0.882618  0.651556  1.698553
# 111159 -0.395162 -3.059942  0.183033 -0.044139  0.022910 -0.940096 -1.735139
# 131697 -0.067604  0.001640 -0.105071 -0.094092  1.226681  0.465300 -0.459292
# 259878 -1.185106 -3.493547  0.173587 -1.258405 -0.780168  0.971511  0.531358
#
# ...

# %%
new_df.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#               V7        V8        V9       V10       V11       V12       V13  \
# 279863 -0.882850  0.697211 -2.064945 -5.587794  2.115795 -5.417424 -1.235123
# 280143 -1.413170  0.248525 -1.127396 -3.232153  2.858466 -3.096915 -0.792532
# 280149 -2.234739  1.210158 -0.652250 -3.463891  1.794969 -2.775022 -0.418950
# 281144 -2.208002  1.058733 -1.632333 -5.245984  1.933520 -5.030465 -1.127455
# 281674  0.223050 -0.068384  0.577829 -0.888722  0.491140  0.728903  0.380428
#
# ...

# %%
new_df.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      95987.650407  0.014880  0.060057  0.067609 -0.138607 -0.021055
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9       V10       V11       V12  \
# Class
# 0     -0.073347 -0.002366  0.025337  0.048720  0.036895 -0.032133  0.010402
# 1     -1.397737 -5.568731  0.570636 -2.581123 -5.676883  3.800173 -6.259393
#
#             V13       V14       V15       V16       V17       V18       V19  \
# Class
# 0      0.013730  0.010381  0.049597 -0.015267 -0.012651  0.006463  0.018176
# 1     -0.109334 -6.971723 -0.092929 -4.139946 -6.665836 -2.246308  0.680659
#
#             V20       V21       V22       V23       V24       V25       V26  \
# Class
# 0      0.035738 -0.028901  0.006191  0.001352  0.056738  0.002044 -0.048960
# 1      0.372319  0.713588  0.014049 -0.040308 -0.105130  0.041449  0.051648
#
# ...

# %%
# Splitting the data into features and target

# %%
X= new_df.drop(columns = 'Class', axis=1)
Y= new_df['Class']
X
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 28898    35223.0 -0.790015  0.874647  1.711628 -1.352299  0.432771 -0.771443
# 41156    40560.0 -0.708047  1.373264  0.598922  0.782221  0.010059 -0.401528
# 111159   72120.0 -2.062005  1.005983 -0.100631  1.240645  0.585214 -0.258625
# 131697   79703.0  1.235649  0.246700  0.175407  0.506931 -0.212665 -0.576058
# 259878  159314.0 -0.352799  0.922197  0.936538 -0.067338 -0.738263  0.282153
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
Y
# Out:
# 28898     0
# 41156     0
# 111159    0
# 131697    0
# 259878    0
#          ..
# 279863    1
# 280143    1
# 280149    1
# 281144    1
# 281674    1
# Name: Class, Length: 984, dtype: int64

# %%
# Split the data into training data & Testing data

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (984, 30) (787, 30) (197, 30)

# %% [markdown]
# ##### Model Training

# %% [markdown]
# #### Logistic Regression

# %%
model = LogisticRegression()

# %%
# Training the logistic Regression model with training data

model.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# ### Model Evaluation

# %% [markdown]
# ####  Accuracy Score

# %%
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print("Accuracy of training data: ", training_data_accuracy)
# Out:
# Accuracy of training data:  0.9491740787801779

# %%
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print("Accuracy of test data: ", test_data_accuracy)
# Out:
# Accuracy of test data:  0.949238578680203
